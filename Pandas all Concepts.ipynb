# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %% [markdown]
# # 1. DataFrame : The stuctured data which is made up of rows and columns like Table

# %%
               # Create Dataframe

df = pd.DataFrame([1,2,3],columns = ["Col_name"])
print(df)
# Out:
#    Col_name
# 0         1
# 1         2
# 2         3

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
data = {
        "Name" :  ["Nikhil","Omkar","Krish","Sai"],
        "Age" : [21,22,23,24],
        "Monthly_Salary" : [30000,40000,50000,54000]
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Age  Monthly_Salary
# 0  Nikhil   21           30000
# 1   Omkar   22           40000
# 2   Krish   23           50000
# 3     Sai   24           54000

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # 2. Basic DataFrame Understanding

# %%
df.head(2)
# Out:
#      Name  Age  Monthly_Salary
# 0  Nikhil   21           30000
# 1   Omkar   22           40000

# %%
df.tail(2)
# Out:
#     Name  Age  Monthly_Salary
# 2  Krish   23           50000
# 3    Sai   24           54000

# %%
df.shape
# Out:
# (4, 3)

# %%
df.columns     # show the all column
# Out:
# Index(['Name', 'Age', 'Monthly_Salary'], dtype='object')

# %%
df.rename(columns = {"Salary": "Monthly_Salary"})
# Out:
#      Name  Age  Monthly_Salary
# 0  Nikhil   21           30000
# 1   Omkar   22           40000
# 2   Krish   23           50000
# 3     Sai   24           54000

# %%
df
# Out:
#      Name  Age  Monthly_Salary
# 0  Nikhil   21           30000
# 1   Omkar   22           40000
# 2   Krish   23           50000
# 3     Sai   24           54000

# %%
df.rename(columns = {"Salary": "Monthly_Salary"},inplace=True)        # inplace
df
# Out:
#      Name  Age  Monthly_Salary
# 0  Nikhil   21           30000
# 1   Omkar   22           40000
# 2   Krish   23           50000
# 3     Sai   24           54000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            4 non-null      object
#  1   Age             4 non-null      int64
#  2   Monthly_Salary  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df.describe()      # it shows statistical summary
# Out:
#              Age  Monthly_Salary
# count   4.000000         4.00000
# mean   22.500000     43500.00000
# std     1.290994     10754.84387
# min    21.000000     30000.00000
# 25%    21.750000     37500.00000
# 50%    22.500000     45000.00000
# 75%    23.250000     51000.00000
# max    24.000000     54000.00000

# %% [markdown]
# # 3. save and load data

# %%
df.to_csv('Test_data.csv', index=False)

# %%
load_df = pd.read_csv('Test_data.csv')
load_df
# Out:
#      Name  Age  Monthly_Salary
# 0  Nikhil   21           30000
# 1   Omkar   22           40000
# 2   Krish   23           50000
# 3     Sai   24           54000

# %% [markdown]
# # 4. Rows and Columns

# %%
# Select Column
# df[["Name"]]  single column

df[["Name"]]
# Out:
#      Name
# 0  Nikhil
# 1   Omkar
# 2   Krish
# 3     Sai

# %%
df[["Name","Monthly_Salary"]]
# Out:
#      Name  Monthly_Salary
# 0  Nikhil           30000
# 1   Omkar           40000
# 2   Krish           50000
# 3     Sai           54000

# %%
# Select Rows

# %%
# loc[] is used for label based indexing

# %%
df.loc[df.Name=="Nikhil"]        # loc is index name based
# Out:
#      Name  Age  Monthly_Salary
# 0  Nikhil   21           30000

# %%
df.loc[(df.Name=="Nikhil")&(df.Monthly_Salary>=25000)]
# Out:
#      Name  Age  Monthly_Salary
# 0  Nikhil   21           30000

# %%
# Rows Selection

# %%
# iloc : index value based

# %%
df.iloc[0]
# Out:
# Name              Nikhil
# Age                   21
# Monthly_Salary     30000
# Name: 0, dtype: object

# %%
df.iloc[0:2]           # [start:stop:step]
# Out:
#      Name  Age  Monthly_Salary
# 0  Nikhil   21           30000
# 1   Omkar   22           40000

# %%
df.loc[0:2]
# Out:
#      Name  Age  Monthly_Salary
# 0  Nikhil   21           30000
# 1   Omkar   22           40000
# 2   Krish   23           50000

# %% [markdown]
# # 5. Filter DataFrame

# %%
# it is used to filter the rows and columns data we can filter by > or < using

# %%
df
# Out:
#      Name  Age  Monthly_Salary
# 0  Nikhil   21           30000
# 1   Omkar   22           40000
# 2   Krish   23           50000
# 3     Sai   24           54000

# %%
df['Age'] > 22
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# Name: Age, dtype: bool

# %%
df[df["Age"] > 22]               # > is used for only greater than
# Out:
#     Name  Age  Monthly_Salary
# 2  Krish   23           50000
# 3    Sai   24           54000

# %%
df[df["Age"] >= 22]              # >= is used for greater than and equqls to
# Out:
#     Name  Age  Monthly_Salary
# 1  Omkar   22           40000
# 2  Krish   23           50000
# 3    Sai   24           54000

# %%
df[(df["Age"] >= 22) & (df["Monthly_Salary"] >= 40000)]       # in this & is used for took more than 1 columns we can take more than 1 column
# Out:
#     Name  Age  Monthly_Salary
# 1  Omkar   22           40000
# 2  Krish   23           50000
# 3    Sai   24           54000

# %%
df.where(df["Age"] >= 23)

# where is used for showing null values to specific rows and columns
# Out:
#     Name   Age  Monthly_Salary
# 0    NaN   NaN             NaN
# 1    NaN   NaN             NaN
# 2  Krish  23.0         50000.0
# 3    Sai  24.0         54000.0

# %%
df.where(df["Age"] >= 23, other = "Not Eligible")
# Out:
#            Name           Age Monthly_Salary
# 0  Not Eligible  Not Eligible   Not Eligible
# 1  Not Eligible  Not Eligible   Not Eligible
# 2         Krish            23          50000
# 3           Sai            24          54000

# %% [markdown]
# # 6. Rows and Columns - Operation (Add,Update,Delete)

# %%
# add new column

df["Team"]= ["CEO","HR","CTO","DA"]                   # added a new column Team
df
# Out:
#      Name  Age  Monthly_Salary Team
# 0  Nikhil   21           30000  CEO
# 1   Omkar   22           40000   HR
# 2   Krish   23           50000  CTO
# 3     Sai   24           54000   DA

# %%
df["Bonus"]= df["Monthly_Salary"]*0.2
df
# Out:
#      Name  Age  Monthly_Salary Team    Bonus
# 0  Nikhil   21           30000  CEO   6000.0
# 1   Omkar   22           40000   HR   8000.0
# 2   Krish   23           50000  CTO  10000.0
# 3     Sai   24           54000   DA  10800.0

# %%
# add new rows

df.loc[len(df)]=['ABC',25,21000,'IT',2000]
df
# Out:
#      Name  Age  Monthly_Salary Team    Bonus
# 0  Nikhil   21           30000  CEO   6000.0
# 1   Omkar   22           40000   HR   8000.0
# 2   Krish   23           50000  CTO  10000.0
# 3     Sai   24           54000   DA  10800.0
# 4     ABC   25           21000   IT   2000.0

# %%
len(df)
# Out:
# 5

# %%
# Update value - Using index value

df.loc[0,"Monthly_Salary"]=35000
df
# Out:
#      Name  Age  Monthly_Salary Team    Bonus
# 0  Nikhil   21           35000  CEO   6000.0
# 1   Omkar   22           40000   HR   8000.0
# 2   Krish   23           50000  CTO  10000.0
# 3     Sai   24           54000   DA  10800.0
# 4     ABC   25           21000   IT   2000.0

# %%
# Updating value - Using Column Value

df.loc[df.Name=="Nikhil","Monthly_Salary"]=30000
df
# Out:
#      Name  Age  Monthly_Salary Team    Bonus
# 0  Nikhil   21           30000  CEO   6000.0
# 1   Omkar   22           40000   HR   8000.0
# 2   Krish   23           50000  CTO  10000.0
# 3     Sai   24           54000   DA  10800.0
# 4     ABC   25           21000   IT   2000.0

# %%
# Delete value - row and column values

df.drop(df[df.Name=="ABC"].index)
# Out:
#      Name  Age  Monthly_Salary Team    Bonus
# 0  Nikhil   21           30000  CEO   6000.0
# 1   Omkar   22           40000   HR   8000.0
# 2   Krish   23           50000  CTO  10000.0
# 3     Sai   24           54000   DA  10800.0

# %%
df[df.Name=="ABC"]
# Out:
#   Name  Age  Monthly_Salary Team   Bonus
# 4  ABC   25           21000   IT  2000.0

# %%
df.drop("Bonus",axis=1)
# Out:
#      Name  Age  Monthly_Salary Team
# 0  Nikhil   21           30000  CEO
# 1   Omkar   22           40000   HR
# 2   Krish   23           50000  CTO
# 3     Sai   24           54000   DA
# 4     ABC   25           21000   IT

# %%
df.drop(["Bonus","Team"],axis=1)
# Out:
#      Name  Age  Monthly_Salary
# 0  Nikhil   21           30000
# 1   Omkar   22           40000
# 2   Krish   23           50000
# 3     Sai   24           54000
# 4     ABC   25           21000

# %%
df.drop(1,axis=0,inplace=True)

# %%
df.drop(df[df.Name=="ABC"].index)          # drop row, axis = 0
df.drop("Bonus",axis=1,inplace=True)       # drop column
df
# Out:
#      Name  Age  Monthly_Salary Team
# 0  Nikhil   21           30000  CEO
# 2   Krish   23           50000  CTO
# 3     Sai   24           54000   DA
# 4     ABC   25           21000   IT

# %%
df
# Out:
#      Name  Age  Monthly_Salary Team
# 0  Nikhil   21           30000  CEO
# 2   Krish   23           50000  CTO
# 3     Sai   24           54000   DA
# 4     ABC   25           21000   IT

# %%
df.sort_values("Monthly_Salary")             # Ascending to Descending order
# Out:
#      Name  Age  Monthly_Salary Team
# 4     ABC   25           21000   IT
# 0  Nikhil   21           30000  CEO
# 2   Krish   23           50000  CTO
# 3     Sai   24           54000   DA

# %%
df.sort_values("Monthly_Salary",ascending = False)     # descending to ascending order
# Out:
#      Name  Age  Monthly_Salary Team
# 3     Sai   24           54000   DA
# 2   Krish   23           50000  CTO
# 0  Nikhil   21           30000  CEO
# 4     ABC   25           21000   IT

# %% [markdown]
# # 7. Working with Date and Value

# %%
df.drop(df[df.Name=="ABC"].index)
# Out:
#      Name  Age  Monthly_Salary Team
# 0  Nikhil   21           30000  CEO
# 2   Krish   23           50000  CTO
# 3     Sai   24           54000   DA

# %%
df
# Out:
#      Name  Age  Monthly_Salary Team
# 0  Nikhil   21           30000  CEO
# 2   Krish   23           50000  CTO
# 3     Sai   24           54000   DA
# 4     ABC   25           21000   IT

# %%
df["DOJ"] = ["2024-01-01", "2024-01-15", "2024-03-28", "2024-03-03"]
df
# Out:
#      Name  Age  Monthly_Salary Team         DOJ
# 0  Nikhil   21           30000  CEO  2024-01-01
# 2   Krish   23           50000  CTO  2024-01-15
# 3     Sai   24           54000   DA  2024-03-28
# 4     ABC   25           21000   IT  2024-03-03

# %%
df["DOJ"].dtype
# Out:
# dtype('O')

# %%
df["Doj"] = pd.to_datetime(df["DOJ"])

# %%
df["DOJ"].dtype
# Out:
# dtype('O')

# %%
df1 = df

# %%
df1["DOJ2"] = ["01-01-2025","15-01-2025","28-03-2025","03-03-2025"]       # Upadated values
df1
# Out:
#      Name  Age  Monthly_Salary Team         DOJ        Doj        DOJ2
# 0  Nikhil   21           30000  CEO  2024-01-01 2024-01-01  01-01-2025
# 2   Krish   23           50000  CTO  2024-01-15 2024-01-15  15-01-2025
# 3     Sai   24           54000   DA  2024-03-28 2024-03-28  28-03-2025
# 4     ABC   25           21000   IT  2024-03-03 2024-03-03  03-03-2025

# %%
df1["DOJ2"].dtype
# Out:
# dtype('O')

# %%
df1["DOJ2"] = pd.to_datetime(df1["DOJ2"],format="%d-%m-%Y")         # Format is used to change the format
df1
# Out:
#      Name  Age  Monthly_Salary Team         DOJ        Doj       DOJ2
# 0  Nikhil   21           30000  CEO  2024-01-01 2024-01-01 2025-01-01
# 2   Krish   23           50000  CTO  2024-01-15 2024-01-15 2025-01-15
# 3     Sai   24           54000   DA  2024-03-28 2024-03-28 2025-03-28
# 4     ABC   25           21000   IT  2024-03-03 2024-03-03 2025-03-03

# %%
df1["DOJ2"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df = df.drop("DOJ2",axis=1)          # delete the last column

# %%
df
# Out:
#      Name  Age  Monthly_Salary Team         DOJ        Doj
# 0  Nikhil   21           30000  CEO  2024-01-01 2024-01-01
# 2   Krish   23           50000  CTO  2024-01-15 2024-01-15
# 3     Sai   24           54000   DA  2024-03-28 2024-03-28
# 4     ABC   25           21000   IT  2024-03-03 2024-03-03

# %% [markdown]
# # Extract year, month, week, day

# %%
df["DOJ"] = pd.to_datetime(df["DOJ"], format="%Y-%m-%d")
df
# Out:
#      Name  Age  Monthly_Salary Team        DOJ        Doj
# 0  Nikhil   21           30000  CEO 2024-01-01 2024-01-01
# 2   Krish   23           50000  CTO 2024-01-15 2024-01-15
# 3     Sai   24           54000   DA 2024-03-28 2024-03-28
# 4     ABC   25           21000   IT 2024-03-03 2024-03-03

# %%
df["DOJ"].dt.year
# Out:
# 0    2024
# 2    2024
# 3    2024
# 4    2024
# Name: DOJ, dtype: int32

# %%
df["DOJ"].dt.month
# Out:
# 0    1
# 2    1
# 3    3
# 4    3
# Name: DOJ, dtype: int32

# %%
df["DOJ"].dt.day_name()
# Out:
# 0      Monday
# 2      Monday
# 3    Thursday
# 4      Sunday
# Name: DOJ, dtype: object

# %%
df["Month"] = df["DOJ"].dt.month      # we can store month in it

# %%
df
# Out:
#      Name  Age  Monthly_Salary Team        DOJ        Doj  Month
# 0  Nikhil   21           30000  CEO 2024-01-01 2024-01-01      1
# 2   Krish   23           50000  CTO 2024-01-15 2024-01-15      1
# 3     Sai   24           54000   DA 2024-03-28 2024-03-28      3
# 4     ABC   25           21000   IT 2024-03-03 2024-03-03      3

# %%
df["DOJ"]+pd.Timedelta(days=90)      # Timedelta, we can add no of days, years in it
                                        # Difference between two dates and times
# Out:
# 0   2024-03-31
# 2   2024-04-14
# 3   2024-06-26
# 4   2024-06-01
# Name: DOJ, dtype: datetime64[ns]

# %% [markdown]
# # 8. Handelling Missing Values

# %%
df
# Out:
#      Name  Age  Monthly_Salary Team        DOJ        Doj  Month
# 0  Nikhil   21           30000  CEO 2024-01-01 2024-01-01      1
# 2   Krish   23           50000  CTO 2024-01-15 2024-01-15      1
# 3     Sai   24           54000   DA 2024-03-28 2024-03-28      3
# 4     ABC   25           21000   IT 2024-03-03 2024-03-03      3

# %%
df.isnull()
# Out:
#     Name    Age  Monthly_Salary   Team    DOJ    Doj  Month
# 0  False  False           False  False  False  False  False
# 2  False  False           False  False  False  False  False
# 3  False  False           False  False  False  False  False
# 4  False  False           False  False  False  False  False

# %%
import numpy as np
df.loc[df.Name == "ABC","Monthly_Salary"] = np.nan
df
# Out:
#      Name  Age  Monthly_Salary Team        DOJ        Doj  Month
# 0  Nikhil   21         30000.0  CEO 2024-01-01 2024-01-01      1
# 2   Krish   23         50000.0  CTO 2024-01-15 2024-01-15      1
# 3     Sai   24         54000.0   DA 2024-03-28 2024-03-28      3
# 4     ABC   25             NaN   IT 2024-03-03 2024-03-03      3

# %%
df.isnull()
# Out:
#     Name    Age  Monthly_Salary   Team    DOJ    Doj  Month
# 0  False  False           False  False  False  False  False
# 2  False  False           False  False  False  False  False
# 3  False  False           False  False  False  False  False
# 4  False  False            True  False  False  False  False

# %%
df.isnull().sum()         # if there are so many data and we have to get only null values then use sum()
# Out:
# Name              0
# Age               0
# Monthly_Salary    1
# Team              0
# DOJ               0
# Doj               0
# Month             0
# dtype: int64

# %%
df.fillna(0)
# Out:
#      Name  Age  Monthly_Salary Team        DOJ        Doj  Month
# 0  Nikhil   21         30000.0  CEO 2024-01-01 2024-01-01      1
# 2   Krish   23         50000.0  CTO 2024-01-15 2024-01-15      1
# 3     Sai   24         54000.0   DA 2024-03-28 2024-03-28      3
# 4     ABC   25             0.0   IT 2024-03-03 2024-03-03      3

# %% [markdown]
# # 9. Aggregation and groupby

# %%
df["Team"].value_counts()
# Out:
# Team
# CEO    1
# CTO    1
# DA     1
# IT     1
# Name: count, dtype: int64

# %%
df["Month"].value_counts()
# Out:
# Month
# 1    2
# 3    2
# Name: count, dtype: int64

# %%
df[df["Month"]==1].value_counts()     # only if we have to take specify values
                                      # value_counts gives frequency of values
# Out:
# Name    Age  Monthly_Salary  Team  DOJ         Doj         Month
# Krish   23   50000.0         CTO   2024-01-15  2024-01-15  1        1
# Nikhil  21   30000.0         CEO   2024-01-01  2024-01-01  1        1
# Name: count, dtype: int64

# %%
# Aggregation based on groupby

df.groupby("Month")["Monthly_Salary"].sum()       # sum() uses when sum of given month salary
# Out:
# Month
# 1    80000.0
# 3    54000.0
# Name: Monthly_Salary, dtype: float64

# %%
df.groupby("Month")["Monthly_Salary"].mean()      # mean() uses when avg Salary have
# Out:
# Month
# 1    40000.0
# 3    54000.0
# Name: Monthly_Salary, dtype: float64

# %%
df.groupby("Month").agg({"Monthly_Salary": "mean", "Name":"count"})        # agg stands for aggregation
# Out:
#        Monthly_Salary  Name
# Month
# 1             40000.0     2
# 3             54000.0     2

# %% [markdown]
# # 10. Concatenate and Merge Dataframes (Joins)

# %%
df1 = pd.DataFrame({"ID":[1,2,3],"Name":["A","B","C"]})

# %%
df1
# Out:
#    ID Name
# 0   1    A
# 1   2    B
# 2   3    C

# %%
df2 = pd.DataFrame({"ID":[1,2,3,4],"Score":[88,96,77,79]})

# %%
df2
# Out:
#    ID  Score
# 0   1     88
# 1   2     96
# 2   3     77
# 3   4     79

# %%
pd.concat([df1, df2],axis = 0)        # vertical / row level / top on top
# Out:
#    ID  Score
# 0   1     88
# 1   2     96
# 2   3     77
# 3   4     79
# 0   1     88
# 1   2     96
# 2   3     77
# 3   4     79

# %%
pd.concat([df1, df2],axis = 1)          # Horizontal / column level / side on side
# Out:
#    ID  Score  ID  Score
# 0   1     88   1     88
# 1   2     96   2     96
# 2   3     77   3     77
# 3   4     79   4     79

# %% [markdown]
# # Merge = Join

# %%
pd.merge(df1,df2, how = "inner", on = "ID")
# Out:
#    ID  Score_x  Score_y
# 0   1       88       88
# 1   2       96       96
# 2   3       77       77
# 3   4       79       79

# %%
pd.merge(df1,df2, how = "left", on = "ID")
# Out:
#    ID  Score_x  Score_y
# 0   1       88       88
# 1   2       96       96
# 2   3       77       77
# 3   4       79       79

# %%
pd.merge(df1,df2, how = "right", on = "ID")
# Out:
#    ID  Score_x  Score_y
# 0   1       88       88
# 1   2       96       96
# 2   3       77       77
# 3   4       79       79

# %%
pd.merge(df1,df2, how = "outer", on = "ID")
# Out:
#    ID  Score_x  Score_y
# 0   1       88       88
# 1   2       96       96
# 2   3       77       77
# 3   4       79       79

# %%
pd.merge(df1, df2, how = "inner", left_on = "ID", right_on = "ID")
# Out:
#    ID  Score_x  Score_y
# 0   1       88       88
# 1   2       96       96
# 2   3       77       77
# 3   4       79       79

# %% [markdown]
# # 11. AI and ChatGPT

# %%
df
# Out:
#      Name  Age  Monthly_Salary Team        DOJ        Doj  Month
# 0  Nikhil   21         30000.0  CEO 2024-01-01 2024-01-01      1
# 2   Krish   23         50000.0  CTO 2024-01-15 2024-01-15      1
# 3     Sai   24         54000.0   DA 2024-03-28 2024-03-28      3
# 4     ABC   25             NaN   IT 2024-03-03 2024-03-03      3

# %%
df[(df["Month"]==1) & (df["Monthly_Salary"] >= 30000)]
# Out:
#      Name  Age  Monthly_Salary Team        DOJ        Doj  Month
# 0  Nikhil   21         30000.0  CEO 2024-01-01 2024-01-01      1
# 2   Krish   23         50000.0  CTO 2024-01-15 2024-01-15      1
